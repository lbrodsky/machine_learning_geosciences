# %%
import sys
print(sys.version)
# Out:
# 3.9.10 (v3.9.10:f2f3f53782, Jan 13 2022, 16:55:46)
# [Clang 13.0.0 (clang-1300.0.29.30)]

# %%
import numpy as np 
print(np.__version__)
# Out:
# 1.26.4

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.6.1

# %%
# coments .... 
a = 1

# %% [markdown]
# # Headline
#
# Some text ...
#
# Example code:
#
# ```
# print('Hello')
# ```
#
# Some more explanations
