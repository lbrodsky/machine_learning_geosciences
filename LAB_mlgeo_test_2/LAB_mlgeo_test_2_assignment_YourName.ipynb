# %% [markdown]
# # ___
#
# # [ Machine Learning in Geosciences ]
#
# ## **Test 2 solution**
#
# *Author: ...*
#
# *Date: ...*
#
# ___

# %% [markdown]
# ### 1.1. The Problem
#
# Classify glacier landscapes in Disko Island, Greenland, using Landsat imagery into three categories:
#
#     1 = Glacier (clear ice)
#
#     2 = Debris-covered glacier
#
#     3 = Rock
#
# This classification helps to understand spatial patterns of glacial melt, especially as debris-covered ice melts at different rates than clean glacier ice.
#
# ### 1.2. Objective
# Build a multiclass machine learning classifier to label glacier terrain types (clear ice, debris-covered ice, rock) from Landsat imagery using reference vector data. The focus is on creating a reliable predictive model, not on generating full prediction maps.
#
# ### 1.3. Assumptions
# * The problem is multivariate classification using spectral and possibly derived features.
# * The input data is batch data — no streaming, so batch learning methods apply.
# * Classification may be challenging due to spectral similarity between debris-covered ice and rock.
# * All pixels with visible ice and/or snow are expected to be glacier ice.
# * The Landsat imagery contains useful spectral bands, indices (e.g., NDSI) may enhance separability.
# * Spatial and class imbalances may exist and shall be assessed during EDA.
#
# ### 1.4. Expected Deliverables
# A complete ML workflow to build and evaluate a model with the following steps:
#
# **Step 1: Task Description (Already completed)**
#
# **Step 2: Exploratory Data Analysis (EDA)**
# - Import Landsat image (6 bands, no thermal).
# - Import vector data with label attribute.
# - Visualize class distributions.
# - Check for class imbalance.
#
# **Step 3: Data Preparation**
# - Extract features from imagery using training polygons.
# - Handle missing data, if any.
# - Split data into train/test sets to avoid leakage.
# - Balance training data if necessary (using SMOTE, undersampling, or class weights).
# Otherwise, confirm balanced dataset.
#
# **Step 4: Model Selection and Training**
# - Consider both linear (Logistic Regression) and non-linear models (e.g. Random Forest, etc.).
# - Determine if non-linearity improves classification of debris vs rock.
# - Train models using cross-validation.
#
# **Step 5: Model Fine-tuning**
# - Perform hyperparameter optimization.
# - Evaluate performance.
#
# **Step 6: Results Interpretation**
# - Report:
#     * Model  accuracy
#     * Generalization gap (train vs test accuracy)
#
# - Discuss:
#     * Limitations
#     * Potential improvements
# ___

# %% [markdown]
# ### Landsat image and reference samples view
#
# 1 = Glacier (red boxes)
#
# 2 = Debris-covered glacier (blue boxes)
#
# 3 = Rock (orange boxes)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Input data description

# %% [markdown]
# * Landsat image (6 bands: Blue, Green, Red, NIR, SWIR1, SWIR2)
#
# * Reference vector file with a label attribute (1: Glacier, 2: Debris, 3: Rock)

# %%
# Download data from Google Drive: 
# https://drive.google.com/drive/folders/1nAhvh3iwlHQhcHRmUdDaTUi6LlkdBR0n?usp=sharing

# file: landsat.tif (~3MB)
# file: disko_glacier_labels.gpkg (~100KB)

# %%
pass

# %% [markdown]
# Submit your solution (Jupyter Notebook with your steps description - justification) to email: lukas.brodsky@natur.cuni.cz
