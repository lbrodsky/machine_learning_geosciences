# %% [markdown]
# # ___
#
# # [ Machine Learning in Geosciences ]
#
# ### | Topic: **GeoPython and Satellite Earth observation (Sentinel-2) for Machine Learning projects**
#
# ### | Thematic focus: vegetation greeness
#
# .....................................................................................................................
#
# Author: *Lukas Brodsky* *lukas.brodsky@natur.cuni.cz*
#
# Project: ESF pro VŠ II na UK | Reg. číslo: CZ.02.2.69/0.0/0.0/18_056/0013322
#
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 1. Problem definition
#
# ### 1.1 Background
#
# Vegetation greenness is a vital indicator of plant health, biomass, and ecosystem productivity. Remote sensing techniques, using satellite imagery, have become essential for monitoring vegetation across large geographic areas. One of the most common measures of vegetation greenness is the Normalized Difference Vegetation Index (NDVI), which is calculated using the red and near-infrared (NIR) bands from satellite images.
#
# Python has become a powerful tool for geospatial data analysis, thanks to libraries such as Rasterio and EarthPy. Rasterio simplifies reading, writing, and processing raster data, while EarthPy provides higher-level functions for working with spatial data and visualizing results effectively. Together, they provide a robust framework for analyzing satellite data and monitoring vegetation changes over time.
#
#
# ### 1.2. Objective:
#
# The objective of this notebook is to demonstrate how to analyze vegetation greenness using satellite imagery with Python. Specifically, this notebook aims to:
#
# * Load and explore raster data using Rasterio.
# * Preprocess satellite imagery for vegetation analysis.
# * Plot the Sentinel-2 bands and histograms.
# * Plot RGB composites of the multispectral imagery.
# * Calculate NDVI from red and near-infrared bands.
# * Visualize NDVI maps using EarthPy.
# * Interpret NDVI values to assess vegetation health and distribution.
# * Calculate other indexes: SAVI, NDMI, etc.
# * Save the results (e.g. NDVI) to file system in GeoTIFF format.
#
# ### 1.3 Expected results
#
# * Learn using GeoPython packages **Rasterio** and **EarthPy** for vegetation greeness calculations using Sentinel-2 satellite imagery.

# %% [markdown]
# ### Rasterio
#
# **Rasterio: access to geospatial raster data**
#
# Geographic information systems use GeoTIFF and other formats to organize and store gridded raster datasets such as satellite imagery and terrain models. Rasterio reads and writes these formats and provides a Python API based on Numpy N-dimensional arrays and GeoJSON.
#
#
# Please refer to **[Rasterio official documentation](https://rasterio.readthedocs.io/en/stable/)**

# %% [markdown]
# ### EarthPy
#
# **EarthPy: A Python Package for Earth Data**
#
# EarthPy is a python package that makes it easier to plot and work with spatial raster and vector data using open source tools. Earthpy depends upon geopandas which has a focus on vector data and rasterio with facilitates input and output of raster data files. It also requires matplotlib for plotting operations.
#
# EarthPy’s goal is to make working with spatial data easier for scientists. Contributions to EarthPy are welcome.
#
# Please refer to **[EarthPy official documentation](https://earthpy.readthedocs.io/en/latest/)**

# %%
# To install rasterio 
# https://rasterio.readthedocs.io/en/stable/installation.html

# ! pip install rasterio 

# python -m pip install --user -U pip
# GDAL_CONFIG=/path/to/gdal-config python -m pip install --user --no-binary rasterio rasterio

# %%
# To install EarthPy, use pip. --upgrade is optional but it ensures that the package overwrites 
# when you install and you have the current version. If you don’t have the package yet you can still 
# use the --upgrade argument.

! pip install earthpy
# Out:
# Requirement already satisfied: earthpy in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (0.9.4)
# Requirement already satisfied: geopandas in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from earthpy) (0.14.2)
# Requirement already satisfied: matplotlib>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from earthpy) (3.7.2)
# Requirement already satisfied: numpy>=1.14.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from earthpy) (1.26.4)
# Requirement already satisfied: rasterio in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from earthpy) (1.3.9)
# Requirement already satisfied: scikit-image in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from earthpy) (0.21.0)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from earthpy) (2.31.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=2.0.0->earthpy) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=2.0.0->earthpy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=2.0.0->earthpy) (4.29.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=2.0.0->earthpy) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=2.0.0->earthpy) (26.0)
# Requirement already satisfied: pillow>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=2.0.0->earthpy) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=2.0.0->earthpy) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=2.0.0->earthpy) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from matplotlib>=2.0.0->earthpy) (6.1.0)
# Requirement already satisfied: zipp>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=2.0.0->earthpy) (3.8.0)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->earthpy) (1.16.0)
# Requirement already satisfied: fiona>=1.8.21 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from geopandas->earthpy) (1.9.5)
# Requirement already satisfied: pandas>=1.4.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from geopandas->earthpy) (2.0.3)
# Requirement already satisfied: pyproj>=3.3.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from geopandas->earthpy) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from geopandas->earthpy) (2.0.2)
# Requirement already satisfied: attrs>=19.2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fiona>=1.8.21->geopandas->earthpy) (26.1.0)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fiona>=1.8.21->geopandas->earthpy) (2024.8.30)
# Requirement already satisfied: click~=8.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fiona>=1.8.21->geopandas->earthpy) (8.1.8)
# Requirement already satisfied: click-plugins>=1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fiona>=1.8.21->geopandas->earthpy) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fiona>=1.8.21->geopandas->earthpy) (0.7.2)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fiona>=1.8.21->geopandas->earthpy) (82.0.1)
# Requirement already satisfied: importlib-metadata in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from fiona>=1.8.21->geopandas->earthpy) (6.8.0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas>=1.4.0->geopandas->earthpy) (2021.3)
# Requirement already satisfied: tzdata>=2022.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from pandas>=1.4.0->geopandas->earthpy) (2023.3)
# Requirement already satisfied: affine in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from rasterio->earthpy) (2.3.1)
# Requirement already satisfied: snuggs>=1.4.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from rasterio->earthpy) (1.4.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->earthpy) (2.0.11)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->earthpy) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->earthpy) (1.26.8)
# Requirement already satisfied: scipy>=1.8 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from scikit-image->earthpy) (1.10.1)
# Requirement already satisfied: networkx>=2.8 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from scikit-image->earthpy) (3.1)
# Requirement already satisfied: imageio>=2.27 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from scikit-image->earthpy) (2.31.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from scikit-image->earthpy) (2023.8.30)
# Requirement already satisfied: PyWavelets>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from scikit-image->earthpy) (1.2.0)
# Requirement already satisfied: lazy_loader>=0.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from scikit-image->earthpy) (0.3)

# %%
import os
from glob import glob
# Rasterio 
import rasterio as rio
import numpy as np
# EarthPy 
# import earthpy as et
# import earthpy.spatial as es
# import earthpy.plot as ep
import plotly.graph_objects as go
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %% [markdown]
# # 2. Data

# %%
# Download data from GDrive: 
# https://drive.google.com/drive/folders/1QEE7RC5MI0ZZO2sl9o8vXPPXsAR3pVnd?usp=drive_link 

# locally
# path = 'C:\\mlgeo\\data\\' # Win path
path = '/Users/lukas/Work/prfuk/ownCloud/Vyuka/Machine_learning_geosciences/data/Sentinel-2_vegetation'
os.chdir(path)

# %%
os.listdir()
# Out:
# ['S2_MSIL2_20240227_T36QUL_subset.tif']

# %%
file_name = os.path.join(path, os.listdir()[0])

# %%
os.path.isfile(file_name)
# Out:
# True

# %% [markdown]
# ### Read image

# %%
# Sentinel-2 bands: blue, green red, 
sentinel2_bands = ['B02', 'B03', 'B04', 'B05', 'B06', 'B07', 'B08', 'B8A', 'B11', 'B12']

# %%
sentinel2_bands
# Out:
# ['B02', 'B03', 'B04', 'B05', 'B06', 'B07', 'B08', 'B8A', 'B11', 'B12']

# %%
# Read the iamge with method open()
with rio.open(file_name, 'r') as f:
    image = f.read()

# %%
image.shape
# Out:
# (10, 614, 985)

# %%
type(image)
# Out:
# numpy.ndarray

# %% [markdown]
# ### Raster metadata

# %%
ds = rio.open(file_name)
ds
# Out:
# <open DatasetReader name='/Users/lukas/Work/prfuk/ownCloud/Vyuka/Machine_learning_geosciences/data/Sentinel-2_vegetation/S2_MSIL2_20240227_T36QUL_subset.tif' mode='r'>

# %%
print(f'Dataset: {ds}')
print(f'Typ datasetu: {type(ds)}')
# Out:
# Dataset: <open DatasetReader name='/Users/lukas/Work/prfuk/ownCloud/Vyuka/Machine_learning_geosciences/data/Sentinel-2_vegetation/S2_MSIL2_20240227_T36QUL_subset.tif' mode='r'>
# Typ datasetu: <class 'rasterio.io.DatasetReader'>

# %%
# Image metadata 
print(f'Bands: {ds.count}') # features for ML 
print(f'Image width: {ds.width}')
print(f'Image height: {ds.height}')
# Out:
# Bands: 10
# Image width: 985
# Image height: 614

# %%
# Raster file metadata 
meta = ds.meta
print(type(meta))
print('Metadata of the dataset: ...')
for k in meta:
    print(k, meta[k])
# Out:
# <class 'dict'>
# Metadata od the dataset: ...
# driver GTiff
# dtype uint16
# nodata 0.0
# width 985
# height 614
# count 10
# crs EPSG:32636
# transform | 20.00, 0.00, 343020.00|
# | 0.00,-20.00, 2558340.00|
# | 0.00, 0.00, 1.00|

# %%
# Bbox
print(f'Bbox: {ds.bounds}')
# Out:
# Bbox: BoundingBox(left=343020.0, bottom=2546060.0, right=362720.0, top=2558340.0)

# %%
# Transformation parameters 
print(f'Geotransformation parameters: {ds.transform}')
# Out:
# Geotransformation parameters: | 20.00, 0.00, 343020.00|
# | 0.00,-20.00, 2558340.00|
# | 0.00, 0.00, 1.00|

# %% [markdown]
# ### Visualize Bands

# %%
ep.plot_bands(image, cmap='gist_earth', figsize=(10, 15), cols=3, cbar = False)

# %% [markdown]
# ### RGB Composite Image

# %%
# RGB Composite Image
rgb = ep.plot_rgb(image, 
                  rgb=(3,2,1), 
                  figsize=(10, 15))

# %%
ep.plot_rgb(
    image,
    rgb=(3, 2, 1),
    stretch=True,
    str_clip=0.1,
    figsize=(10, 15),
    title="RGB Composite Image with Stretch Applied",
)

# %%
# False-colour Composite Image with Strech
ep.plot_rgb(image,
            rgb=(9, 7, 2),
            stretch=True,
            str_clip=0.2,
            figsize=(10, 15), 
            title="False-colour Composite Image with Stretch Applied")

# %%
# False-colour Composite Image with Strech
ep.plot_rgb(image,
            rgb=(7, 9, 4),
            stretch=True,
            str_clip=0.2,
            figsize=(10, 15), 
            title="False-colour Composite Image with Stretch Applied")

# %%
plt.imshow(image[1, :, :], cmap='gray')
plt.colorbar()

# %% [markdown]
# ### Vegetation greeness from Sentinel-2

# %% [markdown]
# To assess vegetation greenness and health, researchers analyze the way plants reflect light in different wavelengths. Healthy vegetation absorbs most visible red light (VIS) for photosynthesis while strongly reflecting near-infrared (NIR) light. The Normalized Difference Vegetation Index (NDVI) is a widely used metric that quantifies vegetation by comparing these reflections. It is calculated as the difference between NIR and red light, normalized over their sum. NDVI values range from -1 to +1, where higher values indicate denser and healthier vegetation, while lower values suggest sparse or stressed plant cover.

# %% [markdown]
# ### NDVI

# %%
from matplotlib.colors import LinearSegmentedColormap
# Define custom colormap where yellow is replaced with white
colors = ["red", "white", "green"]  # Transition from Red -> White -> Green
custom_cmap = LinearSegmentedColormap.from_list("RdWGn", colors, N=256)

# %%
# Normalized differential index: NIR, RED
ndvi = es.normalized_diff(image[7], image[3])

# %%
# Normalized differential index plot
ep.plot_bands(ndvi, cmap="RdYlGn", cols=1, vmin=-1, vmax=1, figsize=(10, 15))

# %%
# NDVI = (NIR - RED)/(NIR + RED) 
nir = image[3, :, :] 
red = image[2, :, :] 
ndvi = (nir - red) / (nir + red)
# Out:
# /var/folders/51/76h6b4vd7s99rjzbn4t681_h0000gp/T/ipykernel_1524/1963231394.py:4: RuntimeWarning: invalid value encountered in divide
#   ndvi = (nir - red) / (nir + red)

# %%
ndvi[ndvi > 1] = 1 
ndvi[ndvi <= -1] = -1

# %%
plt.imshow(ndvi, cmap="RdYlGn")
plt.colorbar()

# %% [markdown]
# ### Writing bands to file

# %%
# prepare metadata
meta = ds.meta
print(f'Metadata datasetu: {meta}')
# Out:
# Metadata datasetu: {'driver': 'GTiff', 'dtype': 'uint16', 'nodata': 0.0, 'width': 985, 'height': 614, 'count': 10, 'crs': CRS.from_epsg(32636), 'transform': Affine(20.0, 0.0, 343020.0,
#        0.0, -20.0, 2558340.0)}

# %%
ndvi
# Out:
# array([[0.13491415, 0.1324747 , 0.13332566, ...,        nan,        nan,
#                nan],
#        [0.13372159, 0.13442096, 0.13255205, ...,        nan,        nan,
#                nan],
#        [0.13431099, 0.13067275, 0.13057361, ...,        nan,        nan,
#                nan],
#        ...,
#        [0.12387892, 0.12183021, 0.12590731, ...,        nan,        nan,
#                nan],
#        [0.12035744, 0.12353853, 0.12463199, ...,        nan,        nan,
#                nan],
#        [0.12083916, 0.12065839, 0.11723761, ...,        nan,        nan,
#                nan]])

# %%
# update what is needed
meta["dtype"] = "float32"
meta['count'] = 1 # 1 band
meta['nodata'] = -2

# %%
print(f'Metadata datasetu: {meta}')
# Out:
# Metadata datasetu: {'driver': 'GTiff', 'dtype': 'float32', 'nodata': -2, 'width': 985, 'height': 614, 'count': 1, 'crs': CRS.from_epsg(32636), 'transform': Affine(20.0, 0.0, 343020.0,
#        0.0, -20.0, 2558340.0)}

# %%
path
# Out:
# '/Users/lukas/Work/prfuk/ownCloud/Vyuka/Machine_learning_geosciences/data/Sentinel-2_vegetation/'

# %%
# write the raster 
out_pthfn = os.path.join(path, 'Sentinel-2_ndvi.tif')

with rio.open(out_pthfn, 'w', **meta) as dst:
    dst.write_band(1, ndvi)

# %%
if os.path.isfile(out_pthfn):
    print('File Sentinel-2_ndvi.tif is written to the filesystem.')
    print(f"The size is: {os.path.getsize(out_pthfn) / 1000000} MB.")
# Out:
# File Sentinel-2_ndvi.tif is written to the filesystem.
# The size is: 2.421374 MB.
