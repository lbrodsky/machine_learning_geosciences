# %% [markdown]
# # ___
#
# # [ Machine Learning in Geosciences ]
#
# ## **ML Workflow exampl**
#
# *Author: lukas.brodsky@natur.cuni.cz*
#
# @KAGIK
#
# ___

# %% [markdown]
# ### 1.1 The Problem
#
# TASK: Predict Forest Fires using Meteorological Data
#
# Context: "Forest fires are a major environmental issue, creating economical and ecological damage while endangering human lives. Fast detection is a key element for controlling such phenomenon. To achieve this, one alternative is to use automatic tools based on local sensors, such as provided by meteorological stations. In effect, meteorological conditions (e.g. temperature, wind) are known to influence forest fires and several fire indexes, such as the forest Fire Weather Index (FWI), you can use such features, see below the figure for feature engineering.
# In this work, we explore a Machine Learning (ML) approach to **predict the burned area of forest fires**.
#
# Published: P. Cortez, Aníbal de Jesus Raimundo Morais (2007):  New Trends in Artificial Intelligence, Proceedings of the 13th EPIA 2007 - Portuguese Conference on Artificial Intelligence
#
# ### 1.2 Assumptions
#
# * The problem is a multivariate regression (will use multiple features to make a prediction);
# * There is no continuous flow of data, hence batch learning shall be applied;
# * The meterological data are good indicators of the forest fire;
# * There are enough variables (features) to predict the forest fire.
#
#
# ### 1.3 Expected results
#
# * Machine Learning model to predict the burned area of the forest fires based on the meterological data.
#
# https://repositorium.uminho.pt/server/api/core/bitstreams/cd830a49-5053-4767-bdee-fcc169ae3c7d/content
#
# Expected MAD (Median Absolute Deviation) is around 12 ha, based on Cortez e tal. (2007).
# ___

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Weather features

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="600">
# </div>

# %% [markdown]
# **Abreviations:**
#
# * Fire Weather Index (FWI)
# * Fine Fuel Moisture Code (FFMC)
# * Duff Moisture Code (DMC)
# * Drought Code (DC)
# * Initial Spread Index (ISI)
# * Buildup Index (BUI)

# %% [markdown]
# ### Input data atrributes description

# %% [markdown]
# **Attribute information**
#
#    1. X - x-axis spatial coordinate within the Montesinho park map: 1 to 9
#    2. Y - y-axis spatial coordinate within the Montesinho park map: 2 to 9
#    3. month - month of the year: "jan" to "dec"
#    4. day - day of the week: "mon" to "sun"
#    5. FFMC - FFMC index from the FWI system: 18.7 to 96.20
#    6. DMC - DMC index from the FWI system: 1.1 to 291.3
#    7. DC - DC index from the FWI system: 7.9 to 860.6
#    8. ISI - ISI index from the FWI system: 0.0 to 56.10
#    9. temp - temperature in Celsius degrees: 2.2 to 33.30
#    10. RH - relative humidity in %: 15.0 to 100
#    11. wind - wind speed in km/h: 0.40 to 9.40
#    12. rain - outside rain in mm/m2 : 0.0 to 6.4
#    13. area - the burned area of the forest (in ha): 0.00 to 1090.84

# %% [markdown]
# #####  Problem definition checklist
#     [x] What exactly is the target variable y?
#     [x] What are the input features X?
#     [x] Is this classification, regression, or another task?
#     [x] What is the unit of observation (pixel, polygon, time step)?
#     [x] Is this prediction or explanation?
#     [x] What assumptions am I making about the process?
#     [?] What would a “good” prediction mean in this context?
#     [Avoid] Is there spatial or temporal structure I must consider?

# %%
import os
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
# Input data 
'./machine_learning_geosciences/06_ML_workflow/data/forestfires.csv'
# Out:
# './machine_learning_geosciences/06_ML_workflow/data/forestfires.csv'

# %%
# Data import - pandas pd.read_csv()
file_path = './data/forestfires.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %% [markdown]
# ### 2. Exploratory Data Analysis (EDA)

# %%
import seaborn as sns

# %%
# plot burnt area - spatial plot
sns.scatterplot(
    data=df,
    x="X",
    y="Y",
    size="area",
    legend=True, 
    sizes=(20, 1000)
)
# Out:
# <Axes: xlabel='X', ylabel='Y'>

# %%
# hsit burned area np.hist plt.hist()
df['area'].hist()
# Out:
# <Axes: >

# %%
# hist of meteo data 
df['temp'].hist()
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['X', 'Y', 'month', 'day', 'FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH',
#        'wind', 'rain', 'area'],
#       dtype='object')

# %%
df_sel = df.copy()

# %%
import calendar
{month: index for index, month in enumerate(calendar.month_abbr) if month}
# Out:
# {'Jan': 1,
#  'Feb': 2,
#  'Mar': 3,
#  'Apr': 4,
#  'May': 5,
#  'Jun': 6,
#  'Jul': 7,
#  'Aug': 8,
#  'Sep': 9,
#  'Oct': 10,
#  'Nov': 11,
#  'Dec': 12}

# %%
df_sel.drop(["month"], inplace=True, axis=1)

# %%
df_sel.drop(["day"], inplace=True, axis=1)

# %%
df_sel.describe()
# Out:
#                 X           Y        FFMC         DMC          DC         ISI  \
# count  517.000000  517.000000  517.000000  517.000000  517.000000  517.000000
# mean     4.669246    4.299807   90.644681  110.872340  547.940039    9.021663
# std      2.313778    1.229900    5.520111   64.046482  248.066192    4.559477
# min      1.000000    2.000000   18.700000    1.100000    7.900000    0.000000
# 25%      3.000000    4.000000   90.200000   68.600000  437.700000    6.500000
# 50%      4.000000    4.000000   91.600000  108.300000  664.200000    8.400000
# 75%      7.000000    5.000000   92.900000  142.400000  713.900000   10.800000
# max      9.000000    9.000000   96.200000  291.300000  860.600000   56.100000
#
#              temp          RH        wind        rain         area
# count  517.000000  517.000000  517.000000  517.000000   517.000000
# mean    18.889168   44.288201    4.017602    0.021663    12.847292
# std      5.806625   16.317469    1.791653    0.295959    63.655818
# min      2.200000   15.000000    0.400000    0.000000     0.000000
# 25%     15.500000   33.000000    2.700000    0.000000     0.000000
# 50%     19.300000   42.000000    4.000000    0.000000     0.520000
# 75%     22.800000   53.000000    4.900000    0.000000     6.570000
# max     33.300000  100.000000    9.400000    6.400000  1090.840000

# %%
corr = df_sel.corr()
corr
# Out:
#              X         Y      FFMC       DMC        DC       ISI      temp  \
# X     1.000000  0.539548 -0.021039 -0.048384 -0.085916  0.006210 -0.051258
# Y     0.539548  1.000000 -0.046308  0.007782 -0.101178 -0.024488 -0.024103
# FFMC -0.021039 -0.046308  1.000000  0.382619  0.330512  0.531805  0.431532
# DMC  -0.048384  0.007782  0.382619  1.000000  0.682192  0.305128  0.469594
# DC   -0.085916 -0.101178  0.330512  0.682192  1.000000  0.229154  0.496208
# ISI   0.006210 -0.024488  0.531805  0.305128  0.229154  1.000000  0.394287
# temp -0.051258 -0.024103  0.431532  0.469594  0.496208  0.394287  1.000000
# RH    0.085223  0.062221 -0.300995  0.073795 -0.039192 -0.132517 -0.527390
# wind  0.018798 -0.020341 -0.028485 -0.105342 -0.203466  0.106826 -0.227116
# rain  0.065387  0.033234  0.056702  0.074790  0.035861  0.067668  0.069491
# area  0.063385  0.044873  0.040122  0.072994  0.049383  0.008258  0.097844
#
#             RH      wind      rain      area
# X     0.085223  0.018798  0.065387  0.063385
# Y     0.062221 -0.020341  0.033234  0.044873
# FFMC -0.300995 -0.028485  0.056702  0.040122
# DMC   0.073795 -0.105342  0.074790  0.072994
# DC   -0.039192 -0.203466  0.035861  0.049383
# ISI  -0.132517  0.106826  0.067668  0.008258
# temp -0.527390 -0.227116  0.069491  0.097844
# RH    1.000000  0.069410  0.099751 -0.075519
# wind  0.069410  1.000000  0.061119  0.012317
# rain  0.099751  0.061119  1.000000 -0.007366
# area -0.075519  0.012317 -0.007366  1.000000

# %%
# corr between features
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <Axes: >

# %%
# explore importance sat/sun days vs. fires

# %% [markdown]
# ##### EDA checklist
#
#     [x] What is the distribution of each feature?
#     [no] Are there missing values? How many?
#     [no] Are there outliers or unrealistic values?
#     [no but log] Is the dataset balanced (for regression)?
#     [] Are features correlated or redundant?
#     [] Are there different regimes or clusters in the data?
#     [x] Does the data reflect real-world variability?
#     [avoid] Are there spatial or temporal patterns?

# %% [markdown]
# ### 3. Data preparation

# %%
df[df['area'] > 1]['area'].hist()
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    X  Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
plt.scatter(df['temp'], df['area'])

# %% [markdown]
# ### Do not use SMOGEN, no improvemnt.

# %%
# many 0, some areas > 0 up to 10000 ha 
# logarithm transform 
# df['area'].hist()
df_sel['area_ln'] = np.log2(df['area'] + 1)
df_sel['area_ln'].hist()
# Out:
# <Axes: >

# %%
plt.scatter(df_sel['temp'], df_sel['area_ln'])

# %%
# cat values to numerical

# %%
# split: stratified must!

# %%
# scale!

# %% [markdown]
# #####  Data Preparation chacklist
#
#     [no] Did I split the data before preprocessing?
#     [no] Is there any data leakage (future info, target leakage)?
#     [] Are features scaled/normalized appropriately?
#     [no] How are missing values handled?
#     [ignored] Are categorical variables encoded correctly?
#     [no] Did I remove irrelevant or redundant features?
#     [] Is preprocessing reproducible (pipeline)?

# %% [markdown]
# ### 4. Select and train model

# %%
# non-linear problem BUT I will start with simple multi-variate linear model as baseline

# %%
# next: SVM, Tree-based regresion model

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# define MAD 
def MAD(y, y_hat):
    return (1/y.size) * (np.sum(np.abs(y-y_hat)))

# %%
X = df_sel.copy()
X = X.drop(['area', 'area_ln'], axis=1)

# %%
X.columns
# Out:
# Index(['X', 'Y', 'FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH', 'wind', 'rain'], dtype='object')

# %%
y = df_sel['area_ln']

# %%
# y

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor(random_state=42)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_train_pred = model.predict(X_train)

# %%
mad_train = MAD(y_train, y_train_pred)

# %%
mad_train
# Out:
# 0.658822768567278

# %%
y_test_pred = model.predict(X_test)

# %%
mad_test = MAD(y_test, y_test_pred)

# %%
mad_test
# Out:
# 1.7506941500120956

# %% [markdown]
# #####  Data Preparation checklist
#
#     [nonlinear, difficult, step-wise continuous, ensemble] What assumption does this model make?
#     [ok] Does the data satisfy this assumption?
#     [may be] Is the model too simple (underfitting risk)?
#     [-] Is the model too complex (overfitting risk)?
#     [RF is robust] How sensitive is the model to noise?
#     [avoid] Does the model handle spatial/temporal structure?
#     [yes] Is the model interpretable if needed?
#     [one] Am I comparing multiple models or guessing one?

# %% [markdown]
# ### 5. Model fine-tuning & validation

# %%
# RandomizedSearch on limited models: A/ SVR and B/ RF 
from sklearn.model_selection import GridSearchCV

# %%
# CV folds: 3, 5-10
CV = 3

# %%
parameters = {'n_estimators':[50, 100, 200], 
              'max_depth':[10, 50, 100]
             }

# %%
gsff = GridSearchCV(model, parameters, cv=CV, n_jobs=6, return_train_score=True)

# %%
gsff.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=RandomForestRegressor(max_depth=50, n_estimators=200,
#                                              random_state=42),
#              n_jobs=6,
#              param_grid={'max_depth': [10, 50, 100],
#                          'n_estimators': [50, 100, 200]},
#              return_train_score=True)

# %%
gsff.best_estimator_
# Out:
# RandomForestRegressor(max_depth=50, n_estimators=200, random_state=42)

# %%
# gsff.cv_results_

# %%
gsff.best_score_
# Out:
# -0.11869606146611462

# %%
gsff.scorer_
# Out:
# <class 'sklearn.ensemble._forest.RandomForestRegressor'>.score

# %%
# Median Absolute Deviation (MAD) 
# robust measure of statistical dispersion, representing the median of the absolute deviations 
# from the data's median

# %%
model = RandomForestRegressor(max_depth=50, n_estimators=200, random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=50, n_estimators=200, random_state=42)

# %%
y_train_pred = model.predict(X_train)

# %%
mad_train = MAD(y_train, y_train_pred)
mad_train
# Out:
# 0.6524455522459391

# %%
y_test_pred = model.predict(X_test)

# %%
mad_test = MAD(y_test, y_test_pred)
mad_test
# Out:
# 1.758805685648239

# %%
from sklearn.model_selection import cross_val_score
cv_scores = cross_val_score(
    model, X_train, y_train, cv=5,
    scoring="neg_mean_squared_error"
)

cv_rmse = np.sqrt(-cv_scores.mean())

print("Cross-validation RMSE:", cv_rmse)
# Out:
# Cross-validation RMSE: 2.124893625783323

# %%
from sklearn.metrics import mean_squared_error

# %%
mse_test = mean_squared_error(y_test, y_test_pred)
rmse_test = np.sqrt(mse_test)
print("Test RMSE:", rmse_test)
# Out:
# Test RMSE: 2.1630236089776624

# %%
model.feature_names_in_
# Out:
# array(['X', 'Y', 'FFMC', 'DMC', 'DC', 'ISI', 'temp', 'RH', 'wind', 'rain'],
#       dtype=object)

# %%
model.feature_importances_
# Out:
# array([0.10119469, 0.06758626, 0.08291134, 0.12170289, 0.10579232,
#        0.09389482, 0.19728699, 0.13283546, 0.09566057, 0.00113466])

# %%
errors = y_test - pred_tree

plt.scatter(pred_tree, errors)
plt.axhline(0, color="red")
plt.xlabel("Predictions")
plt.ylabel("Residuals")
plt.title("Residual analysis")
plt.show()

# %% [markdown]
# ###### Model-finetuning & validation checklist
#
#     [] Is my validation strategy appropriate (CV, spatial CV)?
#     [Yes] Is the test set truly unseen?
#     [kind of] Am I tuning hyperparameters on validation (not test)?
#     [] Are results stable across different splits?
#     [] What metric am I optimizing?
#     [] Does the metric reflect the real objective?
#     [] Am I overfitting during tuning?
#     [] Is model performance consistent?

# %% [markdown]
# ### 6. Results interpretation

# %% [markdown]
# ##### Results interpretation checklist
#
#     [generalized enough] How good is the model? (metrics)
#     [higher area, higher residuals] Where does it fail? (error structure)
#     [NA] Why does it fail? (bias/variance, data)
#     [ok] Does it make sense scientifically?
#     [I believe yes] Can we trust it in real-world use?
#
#
# 1. Best model:
#    RF (captures nonlinear relationships)
#
#     Feature importances:  'RH', 'wind', 'DMC'
#
# 3. Overfitting:
#    Occurs at high depth, we limited the depth to 50
#
# 4. Model capacity:
#    Higher capacity → better fit but risk of overfitting, limited through GridSearchCV
#
# 5. Assumptions:
#    Linear model too simple: did not calculate at all
#    Tree better matches environmental complexity
#
# 6. Limitations:
#    - Highly skewed target variable -> we log-transformed
#    - Noise in environmental data -> yes
#    - Spatial/temporal dependence violates IID; yes, but we ignored it.
#    - Random CV may still be optimistic: yes, later we can replace it with a stratification CV.
# 7. Potential improvements:
#     - use RS data to detect dry trees as a potential risk indicator (e.g. NDVI)
